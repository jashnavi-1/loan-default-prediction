# %% [markdown]
# # Loan Default Prediction
#
# ## Phase 1: Data Understanding
#
# ### Objective
#
# The objective of this notebook is to understand the dataset before preprocessing and model building.
#
# In this notebook, we will:
#
# - Load the training and testing datasets
# - Explore the dataset structure
# - Identify the target variable
# - Check data types
# - Find missing values
# - Understand the features

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
train = pd.read_csv("../data/train.csv")
test = pd.read_csv("../data/test.csv")

# %%
train.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
print("Train Shape:", train.shape)
print("Test Shape:", test.shape)
# Out:
# Train Shape: (614, 13)
# Test Shape: (367, 12)

# %%
train.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='str')

# %%
train.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    str
#  1   Gender             601 non-null    str
#  2   Married            611 non-null    str
#  3   Dependents         599 non-null    str
#  4   Education          614 non-null    str
#  5   Self_Employed      582 non-null    str
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    str
#  12  Loan_Status        614 non-null    str
# dtypes: float64(4), int64(1), str(8)
# memory usage: 62.5 KB

# %%
train.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
# Check missing values
train.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# Target variable distribution
train['Loan_Status'].value_counts()
# Out:
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64

# %%
# Target variable as percentages
train['Loan_Status'].value_counts(normalize=True) * 100
# Out:
# Loan_Status
# Y    68.729642
# N    31.270358
# Name: proportion, dtype: float64

# %%
# Separate categorical and numeric columns
categorical_cols = train.select_dtypes(include='object').columns.tolist()
numeric_cols = train.select_dtypes(include=['int64','float64']).columns.tolist()

print("Categorical columns:", categorical_cols)
print("Numeric columns:", numeric_cols)
# Out:
# Categorical columns: ['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Property_Area', 'Loan_Status']
# Numeric columns: ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History']
# C:\Users\srika\AppData\Local\Temp\ipykernel_24932\3972294978.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_cols = train.select_dtypes(include='object').columns.tolist()

# %% [markdown]
# ### Observations
#
# - The dataset has 614 rows and 13 columns.
# - Missing values are present in: Gender, Married, Dependents, Self_Employed,
#   LoanAmount, Loan_Amount_Term, and Credit_History.
# - The target variable (Loan_Status) is imbalanced: ~69% approved vs ~31% rejected.
#   This means accuracy alone won't be a reliable metric later — precision, recall,
#   and ROC-AUC will matter more.

# %% [markdown]
# ### Observations
#
# - The dataset has 614 rows and 13 columns.
# - Missing values are present in 7 columns: Gender (13), Married (3), Dependents (15),
#   Self_Employed (32), LoanAmount (22), Loan_Amount_Term (14), and Credit_History (50).
# - The target variable (Loan_Status) is imbalanced — 68.7% Approved vs 31.3% Rejected.
#   This means accuracy alone will not be a reliable evaluation metric; precision, recall,
#   and ROC-AUC will be used alongside it in later phases.
# - 8 categorical columns and 5 numeric columns were identified, which will guide the
#   encoding strategy in the data cleaning phase.
